# %%
pythonlist = ['Ama', 54, 'Kojo', 45.5, 'Yhup', 52, 'Kwame', 96, 'Kwesi', 87, 'Roland', True, 'Nti',
             45, 78.5, 'William', 68, 45.3, 78, 'Patty', False, 98, True, 'Adwoa',21, 65, 'Pappy',
             14, 'Folly', False, 52, 'Pency']

# %% [markdown]
# #### Question 1

# %%
list_Floats = []
list_Ints = []
list_Strings = []
list_Booleans = []

# %% [markdown]
# #### Question 2

# %%
for x in pythonlist:
    if type(x) == float:
        list_Floats.append(x)

# %%
print(list_Floats)
# Out:
# [45.5, 78.5, 45.3]

# %%
for x in pythonlist:
    if type(x) == int:
        list_Ints.append(x)

# %%
print(list_Ints)
# Out:
# [54, 52, 96, 87, 45, 68, 78, 98, 21, 65, 14, 52]

# %%
for x in pythonlist:
    if type(x) == str:
        list_Strings.append(x)

# %%
print(list_Strings)
# Out:
# ['Ama', 'Kojo', 'Yhup', 'Kwame', 'Kwesi', 'Roland', 'Nti', 'William', 'Patty', 'Adwoa', 'Pappy', 'Folly', 'Pency']

# %%
for x in pythonlist:
    if type(x) == bool:
        list_Booleans.append(x)

# %%
print(list_Booleans)
# Out:
# [True, False, True, False]

# %% [markdown]
# #### Question 3

# %%
list_Strings.sort()
print(list_Strings)
# Out:
# ['Adwoa', 'Ama', 'Folly', 'Kojo', 'Kwame', 'Kwesi', 'Nti', 'Pappy', 'Patty', 'Pency', 'Roland', 'William', 'Yhup']

# %%
list_Booleans.sort()
print(list_Booleans)
# Out:
# [False, False, True, True]

# %% [markdown]
# #### Question 4

# %%
sorted(list_Ints)[-5:-2:2]
# Out:
# [68, 87]

# %% [markdown]
# #### Question 5

# %%
sorted(list_Floats)[-2]
# Out:
# 45.5
